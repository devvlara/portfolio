# %%
import pandas as pd

# %% [markdown]
# ## Load the Raw Data

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('listings_raw_sale.csv')

# Show the first few rows of the DataFrame to understand its structure
df
# Out:
#            zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0    26683152.0         ForSale           For Sale by Agent
# 1    26809367.0         ForSale           For Sale by Agent
# 2    26903542.0         ForSale           For Sale by Agent
# 3    26813671.0         ForSale           For Sale by Agent
# 4    96527896.0         ForSale           For Sale by Agent
# ..          ...             ...                         ...
# 496  26730486.0         ForSale           For Sale by Agent
# 497  26788275.0         ForSale           For Sale by Agent
# 498  26702531.0         ForSale           For Sale by Agent
# 499  26825874.0         ForSale           For Sale by Agent
# 500         NaN             NaN                         NaN
#
#                                                 imgSrc hasImage  \
# 0    https://photos.zillowstatic.com/fp/fd47d82cf21...     True
# 1    https://photos.zillowstatic.com/fp/540e65ee165...     True
# 2    https://photos.zillowstatic.com/fp/5f815fecdae...     True
# 3    https://photos.zillowstatic.com/fp/190d19818f2...     True
# 4    https://photos.zillowstatic.com/fp/47f73fa0d00...     True
# ..                                                 ...      ...
# 496  https://photos.zillowstatic.com/fp/68d68964e4e...     True
# 497  https://photos.zillowstatic.com/fp/36f53b487e7...     True
# 498  https://photos.zillowstatic.com/fp/039eaac5895...     True
# 499  https://photos.zillowstatic.com/fp/9da46d2cf9b...     True
# 500  https://photos.zillowstatic.com/fp/21b281e7f76...     True
#
#                                              detailUrl statusType  \
# 0    /homedetails/4044-Buena-Vista-St-APT-218-Dalla...   FOR_SALE
# 1    /homedetails/3223-Whitehall-Dr-Dallas-TX-75229...   FOR_SALE
# 2    /homedetails/10777-Strait-Ln-Dallas-TX-75229/2...   FOR_SALE
# 3    /homedetails/5525-Glen-Forest-Ln-Dallas-TX-752...   FOR_SALE
# 4    /homedetails/4002-Agnes-St-Dallas-TX-75210/965...   FOR_SALE
# ..                                                 ...        ...
# 496  /homedetails/1614-Engle-Ave-Dallas-TX-75224/26...   FOR_SALE
# 497  /homedetails/3519-Nogales-Dr-Dallas-TX-75220/2...   FOR_SALE
# 498  /homedetails/6240-Marquita-Ave-Dallas-TX-75214...   FOR_SALE
# 499  /homedetails/1627-Heather-Glen-Dr-Dallas-TX-75...   FOR_SALE
# 500  /community/wright-farms-cottage-collection/303...   FOR_SALE
#
#                      statusText          price priceLabel  ... brokerName  \
# 0                Condo for sale       $325,000      $325K  ...        NaN
# 1                House for sale       $525,000      $525K  ...        NaN
# 2                House for sale    $40,000,000     $40.0M  ...        NaN
# 3                House for sale       $300,000      $300K  ...        NaN
# 4                House for sale       $300,000      $300K  ...        NaN
# ..                          ...            ...        ...  ...        ...
# 496              House for sale       $349,900      $350K  ...        NaN
# 497  Multi-family home for sale       $328,500      $329K  ...        NaN
# 498              House for sale       $925,000      $925K  ...        NaN
# 499              House for sale       $300,000      $300K  ...        NaN
# 500                         NaN  From $229,999        NaN  ...        NaN
#
#      lotAreaString  streetViewURL  streetViewMetadataURL  \
# 0              NaN            NaN                    NaN
# 1              NaN            NaN                    NaN
# 2              NaN            NaN                    NaN
# 3              NaN            NaN                    NaN
# 4              NaN            NaN                    NaN
# ..             ...            ...                    ...
# 496            NaN            NaN                    NaN
# 497            NaN            NaN                    NaN
# 498            NaN            NaN                    NaN
# 499            NaN            NaN                    NaN
# 500            NaN            NaN                    NaN
#
#                          communityName builderName  \
# 0                                  NaN         NaN
# 1                                  NaN         NaN
# 2                                  NaN         NaN
# 3                                  NaN         NaN
# 4                                  NaN         NaN
# ..                                 ...         ...
# 496                                NaN         NaN
# 497                                NaN         NaN
# 498                                NaN         NaN
# 499                                NaN         NaN
# 500  Wright Farms : Cottage Collection      Lennar
#
#     hdpData.homeInfo.providerListingID        plid isCdpResult  \
# 0                                  NaN         NaN         NaN
# 1                                  NaN         NaN         NaN
# 2                                  NaN         NaN         NaN
# 3                                  NaN         NaN         NaN
# 4                                  NaN         NaN         NaN
# ..                                 ...         ...         ...
# 496                                NaN         NaN         NaN
# 497                                NaN         NaN         NaN
# 498                                NaN         NaN         NaN
# 499                                NaN         NaN         NaN
# 500                                NaN  30361291.0        True
#
#     isComingSoonCommunity
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 496                   NaN
# 497                   NaN
# 498                   NaN
# 499                   NaN
# 500                 False
#
# [501 rows x 95 columns]

# %% [markdown]
# ## Functions

# %%
def convert_sqft_to_acres(df):
    # Conversion factor from square feet to acres
    sqft_to_acres = 1 / 43560

    # Using the .loc accessor to modify rows where the Lot Area Unit is 'sqft'
    # Convert and round the area to three decimal places
    df.loc[df['lotareaunit'] == 'sqft', 'lotareavalue'] = (df['lotareavalue'] * sqft_to_acres).round(3)
    df.loc[df['lotareaunit'] == 'sqft', 'lotareaunit'] = 'acres'

    df.loc[df['lotareaunit'] == 'acres', 'lotareavalue'] = (df['lotareavalue']).round(3)
   
    
    return df

# %% [markdown]
# ## Columns to Keep in Data Frame

# %%
df.columns
# Out:
# Index(['zpid', 'rawHomeStatusCd', 'marketingStatusSimplifiedCd', 'imgSrc',
#        'hasImage', 'detailUrl', 'statusType', 'statusText', 'price',
#        'priceLabel', 'address', 'beds', 'baths', 'area', 'flexFieldText',
#        'flexFieldType', 'isUserClaimingOwner', 'isUserConfirmedClaim', 'pgapt',
#        'sgapt', 'shouldShowZestimateAsPrice', 'has3DModel', 'hasVideo',
#        'isHomeRec', 'hasAdditionalAttributions', 'isFeaturedListing',
#        'isShowcaseListing', 'listingType', 'isFavorite', 'visited',
#        'timeOnZillow', 'latLong.latitude', 'latLong.longitude',
#        'hdpData.homeInfo.zpid', 'hdpData.homeInfo.streetAddress',
#        'hdpData.homeInfo.zipcode', 'hdpData.homeInfo.city',
#        'hdpData.homeInfo.state', 'hdpData.homeInfo.latitude',
#        'hdpData.homeInfo.longitude', 'hdpData.homeInfo.price',
#        'hdpData.homeInfo.bathrooms', 'hdpData.homeInfo.bedrooms',
#        'hdpData.homeInfo.livingArea', 'hdpData.homeInfo.homeType',
#        'hdpData.homeInfo.homeStatus', 'hdpData.homeInfo.daysOnZillow',
#        'hdpData.homeInfo.isFeatured', 'hdpData.homeInfo.shouldHighlight',
#        'hdpData.homeInfo.listing_sub_type.is_FSBA',
#        'hdpData.homeInfo.isUnmappable',
#        'hdpData.homeInfo.isPreforeclosureAuction',
#        'hdpData.homeInfo.homeStatusForHDP', 'hdpData.homeInfo.priceForHDP',
#        'hdpData.homeInfo.timeOnZillow', 'hdpData.homeInfo.isNonOwnerOccupied',
#        'hdpData.homeInfo.isPremierBuilder', 'hdpData.homeInfo.isZillowOwned',
#        'hdpData.homeInfo.currency', 'hdpData.homeInfo.country',
#        'hdpData.homeInfo.taxAssessedValue', 'hdpData.homeInfo.unit',
#        'hdpData.homeInfo.lotAreaValue', 'hdpData.homeInfo.lotAreaUnit',
#        'hdpData.homeInfo.isShowcaseListing',
#        'hdpData.homeInfo.datePriceChanged', 'hdpData.homeInfo.zestimate',
#        'hdpData.homeInfo.rentZestimate', 'hdpData.homeInfo.priceReduction',
#        'hdpData.homeInfo.priceChange', 'hdpData.homeInfo.videoCount',
#        'minBeds', 'minBaths', 'minArea', 'lotId', 'buildingId', 'isBuilding',
#        'canSaveBuilding', 'unitCount',
#        'hdpData.homeInfo.listing_sub_type.is_openHouse',
#        'hdpData.homeInfo.openHouse',
#        'hdpData.homeInfo.open_house_info.open_house_showing',
#        'hdpData.homeInfo.listing_sub_type.is_newHome',
#        'hdpData.homeInfo.newConstructionType', 'availabilityDate',
#        'brokerName', 'lotAreaString', 'streetViewURL', 'streetViewMetadataURL',
#        'communityName', 'builderName', 'hdpData.homeInfo.providerListingID',
#        'plid', 'isCdpResult', 'isComingSoonCommunity'],
#       dtype='object')

# %%
# Pick the Columns I want to Keep
columns_to_keep = [

    'zpid', 
    'marketingStatusSimplifiedCd', 
    'statusText', 
    'address', 
    'beds', 
    'baths', 
    'area', 
    'flexFieldText',
    'flexFieldType', 
    'timeOnZillow', 
    'latLong.latitude', 
    'latLong.longitude',
    'hdpData.homeInfo.streetAddress',
    'hdpData.homeInfo.zipcode', 
    'hdpData.homeInfo.city',
    'hdpData.homeInfo.state', 
    'hdpData.homeInfo.price',
    'hdpData.homeInfo.livingArea', 
    'hdpData.homeInfo.homeType',
    'hdpData.homeInfo.taxAssessedValue',
    'hdpData.homeInfo.lotAreaValue', 
    'hdpData.homeInfo.lotAreaUnit',
    'hdpData.homeInfo.datePriceChanged', 
    'hdpData.homeInfo.zestimate',
    'hdpData.homeInfo.rentZestimate',
    'hdpData.homeInfo.priceChange', 
    'detailUrl', 
    'streetViewURL', 
    'streetViewMetadataURL',
     ]

df[columns_to_keep]
df = df[columns_to_keep]

# %% [markdown]
# ## Rename Columns

# %%
column_rename = {

    'zpid' : 'zipid', 
    'marketingStatusSimplifiedCd' : 'sellertype', 
    'statusText' : 'marketstatus', 
    'address' : 'fulladdress', 
    'beds' : 'beds', 
    'baths' : 'baths', 
    'area' : 'sqft', 
    'flexFieldText' : 'update',
    'flexFieldType' : 'updatetype', 
    'timeOnZillow' : 'timeonzillow', 
    'latLong.latitude' : 'latitude', 
    'latLong.longitude' : 'longitude',
    'hdpData.homeInfo.streetAddress' : 'streetaddress',
    'hdpData.homeInfo.zipcode' : 'zipcode', 
    'hdpData.homeInfo.city' : 'city',
    'hdpData.homeInfo.state' : 'state', 
    'hdpData.homeInfo.price' : 'price',
    'hdpData.homeInfo.livingArea' : 'livingarea', 
    'hdpData.homeInfo.homeType' : 'hometype',
    'hdpData.homeInfo.taxAssessedValue' : 'taxassessedvalue',
    'hdpData.homeInfo.lotAreaValue' : 'lotareavalue', 
    'hdpData.homeInfo.lotAreaUnit' : 'lotareaunit',
    'hdpData.homeInfo.datePriceChanged' : 'datepricechange', 
    'hdpData.homeInfo.zestimate' : 'zestimate',
    'hdpData.homeInfo.rentZestimate' : 'rentzestimate',
    'hdpData.homeInfo.priceChange' : 'pricechange', 
    'detailUrl' : 'url', 
    'streetViewURL' : 'streetviewurl', 
    'streetViewMetadataURL' : 'streetviewmetadataurl',


}

# Rename columns
df = df.rename(columns=column_rename)

# %% [markdown]
# ## Convert Sqft to Acres

# %%
df = convert_sqft_to_acres(df)

# %% [markdown]
# ## Convert Datatypes

# %%
columns_to_convert = ['zipid', 'timeonzillow', 'zipcode', 'price', 'livingarea', 'taxassessedvalue', 'zestimate', 'rentzestimate', ]

df[columns_to_convert] = df[columns_to_convert].fillna(0).astype(int)


df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
df = df[df['marketstatus'] != 'For Rent']
df
# Out:
#         zipid         sellertype                marketstatus  \
# 0    26683152  For Sale by Agent              Condo for sale
# 1    26809367  For Sale by Agent              House for sale
# 2    26903542  For Sale by Agent              House for sale
# 3    26813671  For Sale by Agent              House for sale
# 4    96527896  For Sale by Agent              House for sale
# ..        ...                ...                         ...
# 496  26730486  For Sale by Agent              House for sale
# 497  26788275  For Sale by Agent  Multi-family home for sale
# 498  26702531  For Sale by Agent              House for sale
# 499  26825874  For Sale by Agent              House for sale
# 500         0                NaN                         NaN
#
#                                        fulladdress  beds  baths     sqft  \
# 0    4044 Buena Vista St APT 218, Dallas, TX 75204   2.0    3.0   1085.0
# 1              3223 Whitehall Dr, Dallas, TX 75229   4.0    3.0   1988.0
# 2                10777 Strait Ln, Dallas, TX 75229   6.0   11.0  17679.0
# 3            5525 Glen Forest Ln, Dallas, TX 75241   4.0    4.0   2910.0
# 4                  4002 Agnes St, Dallas, TX 75210   4.0    3.0   1653.0
# ..                                             ...   ...    ...      ...
# 496               1614 Engle Ave, Dallas, TX 75224   3.0    2.0   1308.0
# 497              3519 Nogales Dr, Dallas, TX 75220   4.0    3.0   1858.0
# 498            6240 Marquita Ave, Dallas, TX 75214   3.0    3.0   2601.0
# 499         1627 Heather Glen Dr, Dallas, TX 75232   3.0    2.0   1632.0
# 500                                            NaN   NaN    NaN      NaN
#
#                  update    updatetype  timeonzillow  ...  taxassessedvalue  \
# 0              Showcase      showcase    1208443000  ...            254980
# 1              Showcase      showcase     370715000  ...            475730
# 2     13 days on Zillow  daysOnZillow    1172569000  ...          10448460
# 3    265 days on Zillow  daysOnZillow   -2147483648  ...            490320
# 4              Showcase      showcase   -2147483648  ...            243480
# ..                  ...           ...           ...  ...               ...
# 496         5 hours ago    timeOnInfo      18094000  ...            180250
# 497   98 days on Zillow  daysOnZillow   -2147483648  ...            197400
# 498   23 days on Zillow  daysOnZillow    2068957000  ...            737380
# 499   30 days on Zillow  daysOnZillow   -2147483648  ...             89770
# 500                 NaN           NaN             0  ...                 0
#
#      lotareavalue lotareaunit  datepricechange zestimate rentzestimate  \
# 0           0.861       acres              NaN         0             0
# 1           0.298       acres     1.713856e+12    535200          3300
# 2           3.304       acres              NaN  36954700         69738
# 3           2.118       acres     1.717225e+12    283300          2829
# 4           0.130       acres              NaN         0          2365
# ..            ...         ...              ...       ...           ...
# 496         0.175       acres              NaN    351500          2100
# 497         0.103       acres     1.714028e+12         0             0
# 498         0.185       acres     1.717225e+12    893500          6035
# 499         0.183       acres     1.713424e+12    287900          1988
# 500           NaN         NaN              NaN         0             0
#
#      pricechange                                                url  \
# 0            NaN  /homedetails/4044-Buena-Vista-St-APT-218-Dalla...
# 1       -17000.0  /homedetails/3223-Whitehall-Dr-Dallas-TX-75229...
# 2            NaN  /homedetails/10777-Strait-Ln-Dallas-TX-75229/2...
# 3       -99000.0  /homedetails/5525-Glen-Forest-Ln-Dallas-TX-752...
# 4            NaN  /homedetails/4002-Agnes-St-Dallas-TX-75210/965...
# ..           ...                                                ...
# 496          NaN  /homedetails/1614-Engle-Ave-Dallas-TX-75224/26...
# 497       -500.0  /homedetails/3519-Nogales-Dr-Dallas-TX-75220/2...
# 498     -50000.0  /homedetails/6240-Marquita-Ave-Dallas-TX-75214...
# 499        100.0  /homedetails/1627-Heather-Glen-Dr-Dallas-TX-75...
# 500          NaN  /community/wright-farms-cottage-collection/303...
#
#     streetviewurl  streetviewmetadataurl
# 0             NaN                    NaN
# 1             NaN                    NaN
# 2             NaN                    NaN
# 3             NaN                    NaN
# 4             NaN                    NaN
# ..            ...                    ...
# 496           NaN                    NaN
# 497           NaN                    NaN
# 498           NaN                    NaN
# 499           NaN                    NaN
# 500           NaN                    NaN
#
# [468 rows x 29 columns]

# %% [markdown]
# ## Download Data Frame as a CSV

# %%
df.to_csv('recently_listed_houses.csv')
